# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1769461364126, experiment_id='0', last_update_time=1769461364126, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/01/26 21:05:33 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/01/26 21:05:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/01/26 21:05:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# default artifacts URI: 'mlflow-artifacts:/1/bac0be78f49b4eee93433e263bd21860/artifacts'
# 🏃 View run skittish-boar-317 at: http://127.0.0.1:5000/#/experiments/1/runs/bac0be78f49b4eee93433e263bd21860
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1769461533230, experiment_id='1', last_update_time=1769461533230, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/0', creation_time=1769461364126, experiment_id='0', last_update_time=1769461364126, lifecycle_stage='active', name='Default', tags={}>]

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.search_registered_models()
# Out:
# []

# %%
client

# %%
run_id = client.search_runs(experiment_ids='1')[0].info.run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# Successfully registered model 'iris-classifier'.
# 2026/01/26 21:12:31 WARNING mlflow.tracking._model_registry.fluent: Run with id bac0be78f49b4eee93433e263bd21860 has no artifacts at artifact path 'models', registering model based on models:/m-0432fa6b30034c3abd40c36daa6e2070 instead
# 2026/01/26 21:12:31 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: iris-classifier, version 1
# Created version '1' of model 'iris-classifier'.
# <ModelVersion: aliases=[], creation_timestamp=1769461951197, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1769461951197, metrics=None, model_id=None, name='iris-classifier', params=None, run_id='bac0be78f49b4eee93433e263bd21860', run_link='', source='models:/m-0432fa6b30034c3abd40c36daa6e2070', status='READY', status_message=None, tags={}, user_id='', version='1'>
